# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")

print(application_df.shape)
application_df.tail()
# Out:
# (34299, 12)
#              EIN                                               NAME  \
# 34294  996009318              THE LIONS CLUB OF HONOLULU KAMEHAMEHA
# 34295  996010315           INTERNATIONAL ASSOCIATION OF LIONS CLUBS
# 34296  996012607                                PTA HAWAII CONGRESS
# 34297  996015768  AMERICAN FEDERATION OF GOVERNMENT EMPLOYEES LO...
# 34298  996086871                           WATERHOUSE CHARITABLE TR
#
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 34294   Association       1          0                      N      5000
# 34295   Association       1          0                      N      5000
# 34296   Association       1          0                      N      5000
# 34297   Association       1          0                      N      5000
# 34298  Co-operative       1      1M-5M                      N  36500179
#
#        IS_SUCCESSFUL
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df_2=application_df.drop(columns=["EIN", "NAME"])
print(application_df_2.shape)
# Out:
# (34299, 10)

# %%
# Determine the number of unique values in each column.
application_df_2.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df_2['APPLICATION_TYPE'].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
app_value_counts=application_df_2['APPLICATION_TYPE'].value_counts()
application_types_to_replace = app_value_counts.loc[lambda x : x <500].keys()

# # Replace in dataframe
for app in application_types_to_replace:
    application_df_2['APPLICATION_TYPE'] = application_df_2['APPLICATION_TYPE'].replace(app,"Other")

# # Check to make sure binning was successful
print(application_df_2.shape)
application_df_2['APPLICATION_TYPE'].value_counts()
# Out:
# (34299, 10)
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
application_df_2['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
application_df_2['CLASSIFICATION'].value_counts().loc[lambda x : x >1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = application_df_2['CLASSIFICATION'].value_counts().loc[lambda x : x <=1500].keys()

# Replace in dataframe
for cls in classifications_to_replace:
    application_df_2['CLASSIFICATION'] = application_df_2['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
print(application_df_2.shape)
print(application_df_2.columns)
application_df_2['CLASSIFICATION'].value_counts()
# Out:
# (34299, 10)
# Index(['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE',
#        'ORGANIZATION', 'STATUS', 'INCOME_AMT', 'SPECIAL_CONSIDERATIONS',
#        'ASK_AMT', 'IS_SUCCESSFUL'],
#       dtype='object')
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`

application_df_with_dummies=pd.get_dummies(application_df_2, columns=['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE', 'ORGANIZATION', 'INCOME_AMT','SPECIAL_CONSIDERATIONS'])

# Concatenate the application_df_2 and the application_dummies
# application_df_with_dummies=pd.concat([application_df_2,application_dummies],axis=1)
# Drop the original education column
# application_df_with_dummies2=application_df_with_dummies.drop(columns=['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE', 'ORGANIZATION', 'INCOME_AMT','SPECIAL_CONSIDERATIONS'])

application_df_with_dummies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34299 entries, 0 to 34298
# Data columns (total 44 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   STATUS                        34299 non-null  int64
#  1   ASK_AMT                       34299 non-null  int64
#  2   IS_SUCCESSFUL                 34299 non-null  int64
#  3   APPLICATION_TYPE_Other        34299 non-null  uint8
#  4   APPLICATION_TYPE_T10          34299 non-null  uint8
#  5   APPLICATION_TYPE_T19          34299 non-null  uint8
#  6   APPLICATION_TYPE_T3           34299 non-null  uint8
#  7   APPLICATION_TYPE_T4           34299 non-null  uint8
#  8   APPLICATION_TYPE_T5           34299 non-null  uint8
#  9   APPLICATION_TYPE_T6           34299 non-null  uint8
#  10  APPLICATION_TYPE_T7           34299 non-null  uint8
#  11  APPLICATION_TYPE_T8           34299 non-null  uint8
#  12  AFFILIATION_CompanySponsored  34299 non-null  uint8
#  13  AFFILIATION_Family/Parent     34299 non-null  uint8
#  14  AFFILIATION_Independent       34299 non-null  uint8
#  15  AFFILIATION_National          34299 non-null  uint8
#  16  AFFILIATION_Other             34299 non-null  uint8
#  17  AFFILIATION_Regional          34299 non-null  uint8
#  18  CLASSIFICATION_C1000          34299 non-null  uint8
#  19  CLASSIFICATION_C1200          34299 non-null  uint8
#  20  CLASSIFICATION_C2000          34299 non-null  uint8
#  21  CLASSIFICATION_C2100          34299 non-null  uint8
#  22  CLASSIFICATION_C3000          34299 non-null  uint8
#  23  CLASSIFICATION_Other          34299 non-null  uint8
#  24  USE_CASE_CommunityServ        34299 non-null  uint8
#  25  USE_CASE_Heathcare            34299 non-null  uint8
#  26  USE_CASE_Other                34299 non-null  uint8
#  27  USE_CASE_Preservation         34299 non-null  uint8
#  28  USE_CASE_ProductDev           34299 non-null  uint8
#  29  ORGANIZATION_Association      34299 non-null  uint8
#  30  ORGANIZATION_Co-operative     34299 non-null  uint8
#  31  ORGANIZATION_Corporation      34299 non-null  uint8
#  32  ORGANIZATION_Trust            34299 non-null  uint8
#  33  INCOME_AMT_0                  34299 non-null  uint8
#  34  INCOME_AMT_1-9999             34299 non-null  uint8
#  35  INCOME_AMT_10000-24999        34299 non-null  uint8
#  36  INCOME_AMT_100000-499999      34299 non-null  uint8
#  37  INCOME_AMT_10M-50M            34299 non-null  uint8
#  38  INCOME_AMT_1M-5M              34299 non-null  uint8
#  39  INCOME_AMT_25000-99999        34299 non-null  uint8
#  40  INCOME_AMT_50M+               34299 non-null  uint8
#  41  INCOME_AMT_5M-10M             34299 non-null  uint8
#  42  SPECIAL_CONSIDERATIONS_N      34299 non-null  uint8
#  43  SPECIAL_CONSIDERATIONS_Y      34299 non-null  uint8
# dtypes: int64(3), uint8(41)
# memory usage: 2.1 MB

# %%
# Split our preprocessed data into our features and target arrays
X=application_df_with_dummies.copy()
# Separate the y variable, the labels
y=application_df_with_dummies["IS_SUCCESSFUL"].values.reshape(-1, 1)
# Separate the X variable, the features
X.drop('IS_SUCCESSFUL', axis=1, inplace=True)

# Split the preprocessed data into a training and testing dataset

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

print(X_train.shape[1])
# Out:
# 43

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
print(len(X_train_scaled))
# Out:
# 25724

# %%
# # Create a method that creates a new Sequential model with hyperparameter options
# def create_model(hp):
#     nn_model = tf.keras.models.Sequential()

#     # Allow kerastuner to decide which activation function to use in hidden layers
#     activation = hp.Choice('activation',['relu','tanh','sigmoid'])

#     # Allow kerastuner to decide number of neurons in first layer
#     nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units',
#         min_value=1,
#         max_value=80,
#         step=2), activation=activation, input_dim=43))

#     # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
#     for i in range(hp.Int('num_layers', 1, 6)):
#         nn_model.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
#             min_value=1,
#             max_value=30,
#             step=2),
#             activation=activation))

#     nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

#     # Compile the model
#     nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])

#     return nn_model

# %%
# # Import the kerastuner library
# !pip install -q -U keras-tuner
# import keras_tuner as kt

# tuner = kt.Hyperband(
#     create_model,
#     objective="val_accuracy",
#     max_epochs=100,
#     hyperband_iterations=2)

# %%
# Run the kerastuner search for best hyperparameters
# tuner.search(X_train_scaled,y_train,epochs=100,validation_data=(X_test_scaled,y_test))
# Out:
# Trial 234 Complete [00h 01m 19s]
# val_accuracy: 0.7313119769096375
#
# Best val_accuracy So Far: 0.7323614954948425
# Total elapsed time: 01h 25m 03s
#
# Search: Running Trial #235
#
# Value             |Best Value So Far |Hyperparameter
# tanh              |relu              |activation
# 63                |33                |first_units
# 5                 |4                 |num_layers
# 13                |7                 |units_0
# 11                |3                 |units_1
# 27                |11                |units_2
# 29                |9                 |units_3
# 7                 |13                |units_4
# 13                |3                 |units_5
# 34                |12                |tuner/epochs
# 0                 |4                 |tuner/initial_epoch
# 1                 |3                 |tuner/bracket
# 0                 |1                 |tuner/round
#
# Epoch 1/34
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5699 - accuracy: 0.7217 - val_loss: 0.5641 - val_accuracy: 0.7244
# Epoch 2/34
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5560 - accuracy: 0.7285 - val_loss: 0.5602 - val_accuracy: 0.7244
# Epoch 3/34
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5530 - accuracy: 0.7297 - val_loss: 0.5573 - val_accuracy: 0.7263
# Epoch 4/34
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5510 - accuracy: 0.7322 - val_loss: 0.5588 - val_accuracy: 0.7230
# Epoch 5/34
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5494 - accuracy: 0.7313 - val_loss: 0.5560 - val_accuracy: 0.7294
# Epoch 6/34
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5485 - accuracy: 0.7319 - val_loss: 0.5558 - val_accuracy: 0.7256
# Epoch 7/34
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5480 - accuracy: 0.7313 - val_loss: 0.5580 - val_accuracy: 0.7240
# Epoch 8/34
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5464 - accuracy: 0.7328 - val_loss: 0.5561 - val_accuracy: 0.7241
# Epoch 9/34
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5461 - accuracy: 0.7325 - val_loss: 0.5555 - val_accuracy: 0.7290
# Epoch 10/34
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5451 - accuracy: 0.7311 - val_loss: 0.5552 - val_accuracy: 0.7254
# Epoch 11/34
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5447 - accuracy: 0.7332 - val_loss: 0.5546 - val_accuracy: 0.7242
# Epoch 12/34
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5433 - accuracy: 0.7343 - val_loss: 0.5553 - val_accuracy: 0.7262
# Epoch 13/34
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5433 - accuracy: 0.7354 - val_loss: 0.5540 - val_accuracy: 0.7300
# Epoch 14/34
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5433 - accuracy: 0.7359 - val_loss: 0.5553 - val_accuracy: 0.7300
# Epoch 15/34
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5426 - accuracy: 0.7350 - val_loss: 0.5545 - val_accuracy: 0.7263
# Epoch 16/34
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5421 - accuracy: 0.7355 - val_loss: 0.5562 - val_accuracy: 0.7272
# Epoch 17/34
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5419 - accuracy: 0.7358 - val_loss: 0.5538 - val_accuracy: 0.7273
# Epoch 18/34
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5412 - accuracy: 0.7353 - val_loss: 0.5544 - val_accuracy: 0.7290
# Epoch 19/34
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5413 - accuracy: 0.7362 - val_loss: 0.5570 - val_accuracy: 0.7220
# Epoch 20/34
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5410 - accuracy: 0.7366 - val_loss: 0.5537 - val_accuracy: 0.7312
# Epoch 21/34
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5406 - accuracy: 0.7359 - val_loss: 0.5541 - val_accuracy: 0.7299
# Epoch 22/34
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5403 - accuracy: 0.7366 - val_loss: 0.5531 - val_accuracy: 0.7292
# Epoch 23/34
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5395 - accuracy: 0.7360 - val_loss: 0.5539 - val_accuracy: 0.7297
# Epoch 24/34
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5396 - accuracy: 0.7374 - val_loss: 0.5523 - val_accuracy: 0.7287
# Epoch 25/34
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5392 - accuracy: 0.7370 - val_loss: 0.5534 - val_accuracy: 0.7303
# Epoch 26/34
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5391 - accuracy: 0.7378 - val_loss: 0.5542 - val_accuracy: 0.7296
# Epoch 27/34
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5385 - accuracy: 0.7374 - val_loss: 0.5555 - val_accuracy: 0.7298
# Epoch 28/34
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5391 - accuracy: 0.7370 - val_loss: 0.5529 - val_accuracy: 0.7300
# Epoch 29/34
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5384 - accuracy: 0.7363 - val_loss: 0.5550 - val_accuracy: 0.7300
# Epoch 30/34
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5381 - accuracy: 0.7374 - val_loss: 0.5547 - val_accuracy: 0.7297
# Epoch 31/34
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5386 - accuracy: 0.7378 - val_loss: 0.5542 - val_accuracy: 0.7285
# Epoch 32/34
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5388 - accuracy: 0.7377 - val_loss: 0.5548 - val_accuracy: 0.7289
# Epoch 33/34
#  15/804 [..............................] - ETA: 2s - loss: 0.5170 - accuracy: 0.7708

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Optimize the original model by adding another hidden layer
number_input_features = X_train.shape[1]
hidden_nodes_layer1 =  80
hidden_nodes_layer2 = 30
hidden_nodes_layer3 = 10

nn1 = tf.keras.models.Sequential()

# First hidden layer
nn1.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn1.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Third hidden layer
nn1.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn1.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn1.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_7 (Dense)             (None, 80)                3520
#
#  dense_8 (Dense)             (None, 30)                2430
#
#  dense_9 (Dense)             (None, 30)                930
#
#  dense_10 (Dense)            (None, 1)                 31
#
# =================================================================
# Total params: 6,911
# Trainable params: 6,911
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn1.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# # Train the model
print(X_train.shape[1])

fit_model = nn1.fit(X_train_scaled,y_train,epochs=100)
# Out:
# 43
# Epoch 1/100
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5685 - accuracy: 0.7211
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5541 - accuracy: 0.7287
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5514 - accuracy: 0.7310
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5496 - accuracy: 0.7323
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5485 - accuracy: 0.7327
# Epoch 6/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5481 - accuracy: 0.7315
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5470 - accuracy: 0.7320
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5461 - accuracy: 0.7334
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5459 - accuracy: 0.7332
# Epoch 10/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5454 - accuracy: 0.7351
# Epoch 11/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5440 - accuracy: 0.7344
# Epoch 12/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5437 - accuracy: 0.7352
# Epoch 13/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5437 - accuracy: 0.7358
# Epoch 14/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5423 - accuracy: 0.7354
# Epoch 15/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5428 - accuracy: 0.7358
# Epoch 16/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5421 - accuracy: 0.7361
# Epoch 17/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5419 - accuracy: 0.7352
# Epoch 18/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5419 - accuracy: 0.7365
# Epoch 19/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5415 - accuracy: 0.7372
# Epoch 20/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5411 - accuracy: 0.7354
# Epoch 21/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5412 - accuracy: 0.7360
# Epoch 22/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5410 - accuracy: 0.7364
# Epoch 23/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5404 - accuracy: 0.7361
# Epoch 24/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5402 - accuracy: 0.7368
# Epoch 25/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5399 - accuracy: 0.7367
# Epoch 26/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5400 - accuracy: 0.7370
# Epoch 27/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5400 - accuracy: 0.7360
# Epoch 28/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5396 - accuracy: 0.7368
# Epoch 29/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5394 - accuracy: 0.7365
# Epoch 30/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5398 - accuracy: 0.7369
# Epoch 31/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5390 - accuracy: 0.7370
# Epoch 32/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5390 - accuracy: 0.7368
# Epoch 33/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5388 - accuracy: 0.7373
# Epoch 34/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5380 - accuracy: 0.7378
# Epoch 35/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5387 - accuracy: 0.7376
# Epoch 36/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5381 - accuracy: 0.7379
# Epoch 37/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5382 - accuracy: 0.7379
# Epoch 38/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5380 - accuracy: 0.7382
# Epoch 39/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5377 - accuracy: 0.7374
# Epoch 40/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5375 - accuracy: 0.7382
# Epoch 41/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5376 - accuracy: 0.7382
# Epoch 42/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5373 - accuracy: 0.7371
# Epoch 43/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5378 - accuracy: 0.7381
# Epoch 44/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5377 - accuracy: 0.7384
# Epoch 45/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5370 - accuracy: 0.7377
# Epoch 46/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5367 - accuracy: 0.7383
# Epoch 47/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5369 - accuracy: 0.7380
# Epoch 48/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5370 - accuracy: 0.7387
# Epoch 49/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5365 - accuracy: 0.7395
# Epoch 50/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5368 - accuracy: 0.7379
# Epoch 51/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5364 - accuracy: 0.7380
# Epoch 52/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5367 - accuracy: 0.7390
# Epoch 53/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5364 - accuracy: 0.7374
# Epoch 54/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5362 - accuracy: 0.7376
# Epoch 55/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5365 - accuracy: 0.7385
# Epoch 56/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5359 - accuracy: 0.7381
# Epoch 57/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5360 - accuracy: 0.7388
# Epoch 58/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5356 - accuracy: 0.7392
# Epoch 59/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5359 - accuracy: 0.7392
# Epoch 60/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5352 - accuracy: 0.7392
# Epoch 61/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5359 - accuracy: 0.7378
# Epoch 62/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5358 - accuracy: 0.7392
# Epoch 63/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5355 - accuracy: 0.7391
# Epoch 64/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5357 - accuracy: 0.7401
# Epoch 65/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5358 - accuracy: 0.7398
# Epoch 66/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5354 - accuracy: 0.7391
# Epoch 67/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5355 - accuracy: 0.7396
# Epoch 68/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5354 - accuracy: 0.7399
# Epoch 69/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5350 - accuracy: 0.7389
# Epoch 70/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5350 - accuracy: 0.7390
# Epoch 71/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5348 - accuracy: 0.7391
# Epoch 72/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5353 - accuracy: 0.7389
# Epoch 73/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5347 - accuracy: 0.7399
# Epoch 74/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5350 - accuracy: 0.7385
# Epoch 75/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5350 - accuracy: 0.7399
# Epoch 76/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5344 - accuracy: 0.7396
# Epoch 77/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5348 - accuracy: 0.7392
# Epoch 78/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5349 - accuracy: 0.7404
# Epoch 79/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5343 - accuracy: 0.7395
# Epoch 80/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5344 - accuracy: 0.7397
# Epoch 81/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5342 - accuracy: 0.7399
# Epoch 82/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5343 - accuracy: 0.7394
# Epoch 83/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5346 - accuracy: 0.7398
# Epoch 84/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5343 - accuracy: 0.7392
# Epoch 85/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5340 - accuracy: 0.7404
# Epoch 86/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5342 - accuracy: 0.7396
# Epoch 87/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5341 - accuracy: 0.7399
# Epoch 88/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5344 - accuracy: 0.7390
# Epoch 89/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5340 - accuracy: 0.7392
# Epoch 90/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5344 - accuracy: 0.7387
# Epoch 91/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5339 - accuracy: 0.7404
# Epoch 92/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5339 - accuracy: 0.7389
# Epoch 93/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5341 - accuracy: 0.7395
# Epoch 94/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5342 - accuracy: 0.7390
# Epoch 95/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5341 - accuracy: 0.7396
# Epoch 96/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5334 - accuracy: 0.7397
# Epoch 97/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5336 - accuracy: 0.7400
# Epoch 98/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5338 - accuracy: 0.7392
# Epoch 99/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5341 - accuracy: 0.7392
# Epoch 100/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5336 - accuracy: 0.7400

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn1.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5771 - accuracy: 0.7279 - 464ms/epoch - 2ms/step
# Loss: 0.5770735144615173, Accuracy: 0.7279300093650818

# %%
# Optimize the model by adding more neurons and replacing rely with tahn
number_input_features = X_train.shape[1]
hidden_nodes_layer1 =  80
hidden_nodes_layer2 = 40 # adding neurons to hidden layers
hidden_nodes_layer3 = 10

nn2 = tf.keras.models.Sequential() # replacing relu with tanh for hidden layers

# First hidden layer
nn2.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="tanh")
)

# Second hidden layer
nn2.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="tanh"))

# Third hidden layer
nn2.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="tanh"))

# Output layer
nn2.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn2.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_11 (Dense)            (None, 80)                3520
#
#  dense_12 (Dense)            (None, 40)                3240
#
#  dense_13 (Dense)            (None, 40)                1640
#
#  dense_14 (Dense)            (None, 1)                 41
#
# =================================================================
# Total params: 8,441
# Trainable params: 8,441
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn2.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
#  Train the model
print(X_train.shape[1])

fit_model = nn2.fit(X_train_scaled,y_train,epochs=100)
# Out:
# 43
# Epoch 1/100
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5690 - accuracy: 0.7250
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5561 - accuracy: 0.7282
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5526 - accuracy: 0.7299
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5504 - accuracy: 0.7311
# Epoch 5/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5493 - accuracy: 0.7306
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5479 - accuracy: 0.7321
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5466 - accuracy: 0.7332
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5457 - accuracy: 0.7332
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5450 - accuracy: 0.7324
# Epoch 10/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5445 - accuracy: 0.7337
# Epoch 11/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5436 - accuracy: 0.7337
# Epoch 12/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5429 - accuracy: 0.7342
# Epoch 13/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5423 - accuracy: 0.7350
# Epoch 14/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5419 - accuracy: 0.7353
# Epoch 15/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5408 - accuracy: 0.7366
# Epoch 16/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5410 - accuracy: 0.7353
# Epoch 17/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5404 - accuracy: 0.7371
# Epoch 18/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5402 - accuracy: 0.7363
# Epoch 19/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5395 - accuracy: 0.7366
# Epoch 20/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5394 - accuracy: 0.7364
# Epoch 21/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5388 - accuracy: 0.7362
# Epoch 22/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5386 - accuracy: 0.7368
# Epoch 23/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5384 - accuracy: 0.7375
# Epoch 24/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5380 - accuracy: 0.7369
# Epoch 25/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5377 - accuracy: 0.7374
# Epoch 26/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5374 - accuracy: 0.7372
# Epoch 27/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5371 - accuracy: 0.7369
# Epoch 28/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5370 - accuracy: 0.7379
# Epoch 29/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5368 - accuracy: 0.7374
# Epoch 30/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5365 - accuracy: 0.7390
# Epoch 31/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5363 - accuracy: 0.7387
# Epoch 32/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5361 - accuracy: 0.7390
# Epoch 33/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5360 - accuracy: 0.7391
# Epoch 34/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5357 - accuracy: 0.7381
# Epoch 35/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5354 - accuracy: 0.7382
# Epoch 36/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5356 - accuracy: 0.7384
# Epoch 37/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5351 - accuracy: 0.7378
# Epoch 38/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5352 - accuracy: 0.7393
# Epoch 39/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5350 - accuracy: 0.7375
# Epoch 40/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5346 - accuracy: 0.7402
# Epoch 41/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5344 - accuracy: 0.7386
# Epoch 42/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5343 - accuracy: 0.7392
# Epoch 43/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5345 - accuracy: 0.7395
# Epoch 44/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5344 - accuracy: 0.7398
# Epoch 45/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5343 - accuracy: 0.7400
# Epoch 46/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5338 - accuracy: 0.7390
# Epoch 47/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5338 - accuracy: 0.7404
# Epoch 48/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5337 - accuracy: 0.7401
# Epoch 49/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5337 - accuracy: 0.7388
# Epoch 50/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5337 - accuracy: 0.7395
# Epoch 51/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5335 - accuracy: 0.7396
# Epoch 52/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5333 - accuracy: 0.7401
# Epoch 53/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5333 - accuracy: 0.7395
# Epoch 54/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5331 - accuracy: 0.7414
# Epoch 55/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5332 - accuracy: 0.7404
# Epoch 56/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5331 - accuracy: 0.7402
# Epoch 57/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5334 - accuracy: 0.7401
# Epoch 58/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5331 - accuracy: 0.7412
# Epoch 59/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5331 - accuracy: 0.7407
# Epoch 60/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5327 - accuracy: 0.7403
# Epoch 61/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5326 - accuracy: 0.7409
# Epoch 62/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5325 - accuracy: 0.7405
# Epoch 63/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5327 - accuracy: 0.7403
# Epoch 64/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5326 - accuracy: 0.7407
# Epoch 65/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5327 - accuracy: 0.7405
# Epoch 66/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5324 - accuracy: 0.7407
# Epoch 67/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5320 - accuracy: 0.7408
# Epoch 68/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5324 - accuracy: 0.7400
# Epoch 69/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5325 - accuracy: 0.7403
# Epoch 70/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5322 - accuracy: 0.7402
# Epoch 71/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5321 - accuracy: 0.7409
# Epoch 72/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5319 - accuracy: 0.7406
# Epoch 73/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5320 - accuracy: 0.7395
# Epoch 74/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5319 - accuracy: 0.7406
# Epoch 75/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5320 - accuracy: 0.7414
# Epoch 76/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5319 - accuracy: 0.7414
# Epoch 77/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5319 - accuracy: 0.7412
# Epoch 78/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5318 - accuracy: 0.7399
# Epoch 79/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5314 - accuracy: 0.7395
# Epoch 80/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5317 - accuracy: 0.7405
# Epoch 81/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5315 - accuracy: 0.7404
# Epoch 82/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5312 - accuracy: 0.7405
# Epoch 83/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5317 - accuracy: 0.7406
# Epoch 84/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5313 - accuracy: 0.7417
# Epoch 85/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5317 - accuracy: 0.7405
# Epoch 86/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5315 - accuracy: 0.7407
# Epoch 87/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5315 - accuracy: 0.7410
# Epoch 88/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5313 - accuracy: 0.7405
# Epoch 89/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5313 - accuracy: 0.7405
# Epoch 90/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5313 - accuracy: 0.7410
# Epoch 91/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5312 - accuracy: 0.7414
# Epoch 92/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5310 - accuracy: 0.7405
# Epoch 93/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5312 - accuracy: 0.7408
# Epoch 94/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5313 - accuracy: 0.7410
# Epoch 95/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5311 - accuracy: 0.7415
# Epoch 96/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5311 - accuracy: 0.7401
# Epoch 97/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5309 - accuracy: 0.7410
# Epoch 98/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5310 - accuracy: 0.7407
# Epoch 99/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5309 - accuracy: 0.7407
# Epoch 100/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5307 - accuracy: 0.7408

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn2.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5634 - accuracy: 0.7275 - 453ms/epoch - 2ms/step
# Loss: 0.5634011626243591, Accuracy: 0.7274635434150696

# %%
# Optimize the model by  decreasing the number of neurons in the input layer and  going back to relu.
number_input_features = X_train.shape[1]
hidden_nodes_layer1 =  60 # decreasing the number of neurons
hidden_nodes_layer2 = 30
hidden_nodes_layer3 = 10

nn3 = tf.keras.models.Sequential() # replacing tanh with relu for hidden layers

# First hidden layer
nn3.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn3.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Third hidden layer
nn3.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn3.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn3.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 60)                2640
#
#  dense_16 (Dense)            (None, 30)                1830
#
#  dense_17 (Dense)            (None, 30)                930
#
#  dense_18 (Dense)            (None, 1)                 31
#
# =================================================================
# Total params: 5,431
# Trainable params: 5,431
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn3.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
#  Train the model
print(X_train.shape[1])

fit_model = nn3.fit(X_train_scaled,y_train,epochs=100)
# Out:
# 43
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5700 - accuracy: 0.7230
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5544 - accuracy: 0.7294
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5525 - accuracy: 0.7299
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5498 - accuracy: 0.7329
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5495 - accuracy: 0.7324
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5486 - accuracy: 0.7315
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5476 - accuracy: 0.7327
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5469 - accuracy: 0.7330
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5458 - accuracy: 0.7340
# Epoch 10/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5455 - accuracy: 0.7343
# Epoch 11/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5450 - accuracy: 0.7346
# Epoch 12/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5443 - accuracy: 0.7343
# Epoch 13/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5442 - accuracy: 0.7347
# Epoch 14/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5435 - accuracy: 0.7338
# Epoch 15/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5430 - accuracy: 0.7347
# Epoch 16/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5426 - accuracy: 0.7351
# Epoch 17/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5427 - accuracy: 0.7351
# Epoch 18/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5424 - accuracy: 0.7341
# Epoch 19/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5426 - accuracy: 0.7372
# Epoch 20/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5420 - accuracy: 0.7348
# Epoch 21/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5423 - accuracy: 0.7364
# Epoch 22/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5415 - accuracy: 0.7358
# Epoch 23/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5412 - accuracy: 0.7371
# Epoch 24/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5411 - accuracy: 0.7357
# Epoch 25/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5406 - accuracy: 0.7372
# Epoch 26/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5408 - accuracy: 0.7358
# Epoch 27/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5401 - accuracy: 0.7367
# Epoch 28/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5398 - accuracy: 0.7367
# Epoch 29/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5402 - accuracy: 0.7370
# Epoch 30/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5398 - accuracy: 0.7375
# Epoch 31/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5397 - accuracy: 0.7371
# Epoch 32/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5398 - accuracy: 0.7372
# Epoch 33/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5394 - accuracy: 0.7364
# Epoch 34/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5392 - accuracy: 0.7377
# Epoch 35/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5390 - accuracy: 0.7385
# Epoch 36/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5390 - accuracy: 0.7384
# Epoch 37/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5388 - accuracy: 0.7394
# Epoch 38/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5385 - accuracy: 0.7367
# Epoch 39/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5383 - accuracy: 0.7385
# Epoch 40/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5392 - accuracy: 0.7380
# Epoch 41/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5383 - accuracy: 0.7367
# Epoch 42/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5382 - accuracy: 0.7386
# Epoch 43/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5377 - accuracy: 0.7377
# Epoch 44/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5379 - accuracy: 0.7381
# Epoch 45/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5381 - accuracy: 0.7384
# Epoch 46/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5380 - accuracy: 0.7376
# Epoch 47/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5376 - accuracy: 0.7390
# Epoch 48/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5376 - accuracy: 0.7390
# Epoch 49/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5377 - accuracy: 0.7386
# Epoch 50/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5371 - accuracy: 0.7387
# Epoch 51/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5375 - accuracy: 0.7395
# Epoch 52/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5374 - accuracy: 0.7393
# Epoch 53/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5373 - accuracy: 0.7386
# Epoch 54/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5369 - accuracy: 0.7390
# Epoch 55/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5372 - accuracy: 0.7385
# Epoch 56/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5365 - accuracy: 0.7393
# Epoch 57/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5366 - accuracy: 0.7386
# Epoch 58/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5367 - accuracy: 0.7391
# Epoch 59/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5363 - accuracy: 0.7386
# Epoch 60/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5362 - accuracy: 0.7392
# Epoch 61/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5366 - accuracy: 0.7388
# Epoch 62/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5366 - accuracy: 0.7391
# Epoch 63/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5366 - accuracy: 0.7397
# Epoch 64/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5364 - accuracy: 0.7395
# Epoch 65/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5356 - accuracy: 0.7398
# Epoch 66/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5354 - accuracy: 0.7397
# Epoch 67/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5360 - accuracy: 0.7386
# Epoch 68/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5360 - accuracy: 0.7395
# Epoch 69/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5358 - accuracy: 0.7385
# Epoch 70/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5355 - accuracy: 0.7386
# Epoch 71/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5360 - accuracy: 0.7393
# Epoch 72/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5355 - accuracy: 0.7402
# Epoch 73/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5359 - accuracy: 0.7391
# Epoch 74/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5351 - accuracy: 0.7384
# Epoch 75/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5355 - accuracy: 0.7390
# Epoch 76/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5354 - accuracy: 0.7397
# Epoch 77/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5359 - accuracy: 0.7386
# Epoch 78/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5352 - accuracy: 0.7398
# Epoch 79/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5350 - accuracy: 0.7397
# Epoch 80/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5349 - accuracy: 0.7397
# Epoch 81/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5357 - accuracy: 0.7397
# Epoch 82/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5351 - accuracy: 0.7395
# Epoch 83/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5345 - accuracy: 0.7400
# Epoch 84/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5347 - accuracy: 0.7399
# Epoch 85/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5351 - accuracy: 0.7397
# Epoch 86/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5350 - accuracy: 0.7409
# Epoch 87/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5345 - accuracy: 0.7395
# Epoch 88/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5342 - accuracy: 0.7401
# Epoch 89/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5343 - accuracy: 0.7393
# Epoch 90/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5347 - accuracy: 0.7397
# Epoch 91/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5342 - accuracy: 0.7402
# Epoch 92/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5346 - accuracy: 0.7401
# Epoch 93/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5341 - accuracy: 0.7399
# Epoch 94/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5341 - accuracy: 0.7399
# Epoch 95/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5346 - accuracy: 0.7405
# Epoch 96/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5341 - accuracy: 0.7399
# Epoch 97/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5343 - accuracy: 0.7408
# Epoch 98/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5344 - accuracy: 0.7394
# Epoch 99/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5337 - accuracy: 0.7399
# Epoch 100/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5337 - accuracy: 0.7406

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn3.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5668 - accuracy: 0.7285 - 439ms/epoch - 2ms/step
# Loss: 0.5668317675590515, Accuracy: 0.7285131216049194

# %%
nn3.save("AlphabetSoupCharity_Optimization.h5")
